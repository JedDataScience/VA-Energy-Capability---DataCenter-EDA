# %% [markdown]
# # How Data Centers Shape Virginia's Energy Capability

# %% [markdown]
# ![My Infographic](Design_Final_Project/Final_Product/Data_center_and_VA_infographic.png)

# %% [markdown]
# ## Articles I read and used to gain more knowledge on the subject
#
# - https://www.pecva.org/our-work/energy-matters/data-centers-energy-demand/
# - https://www.selc.org/news/overhyped-data-center-growth-is-shaping-our-energy-future/
# - https://www.mordorintelligence.com/industry-reports/northern-virginia-data-center-market
